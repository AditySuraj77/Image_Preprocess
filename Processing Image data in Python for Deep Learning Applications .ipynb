# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array,array_to_img

# %% [markdown]
# ## Read Images

# %%
img = load_img('C:\\Users\\user.LAPTOP\\Desktop\\Deep Learning Projects\\elephant.jfif')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x563>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_arra = img_to_array(img)

# %%
print(img_arra)
# Out:
# [[[219. 222. 237.]
#   [218. 221. 236.]
#   [215. 218. 233.]
#   ...
#   [202. 207. 226.]
#   [202. 207. 226.]
#   [202. 207. 226.]]
#
#  [[216. 219. 234.]
#   [215. 218. 233.]
#   [213. 216. 231.]
#   ...
#   [202. 207. 226.]
#   [202. 207. 226.]
#   [202. 207. 226.]]
#
#  [[211. 214. 229.]
#   [211. 214. 229.]
#   [210. 213. 228.]
#   ...
#   [202. 207. 226.]
#   [202. 207. 226.]
#   [202. 207. 226.]]
#
#  ...
#
#  [[128.  95.  62.]
#   [138. 105.  70.]
#   [123.  91.  53.]
#   ...
#   [158. 122.  88.]
#   [149. 111.  75.]
#   [163. 125.  89.]]
#
#  [[119.  86.  53.]
#   [133. 100.  65.]
#   [139. 105.  68.]
#   ...
#   [148. 112.  76.]
#   [150. 112.  76.]
#   [147. 109.  73.]]
#
#  [[138. 105.  72.]
#   [149. 116.  81.]
#   [159. 125.  88.]
#   ...
#   [146. 110.  74.]
#   [158. 120.  84.]
#   [133.  95.  58.]]]

# %%
img_arra.shape # Cheking image dimensions
# Out:
# (563, 1000, 3)

# %%
type(img_arra) # Checking image type
# Out:
# numpy.ndarray

# %% [markdown]
# # Resize the image

# %%
from PIL import Image

# %%
r_img = Image.open('C:\\Users\\user.LAPTOP\\Desktop\\Deep Learning Projects\\elephant.jfif')

# %%
r_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x563>

# %%
r_img_resize = r_img.resize((200,200))

# %%
save_r_img = r_img_resize.save('Elephant_resize_img.jpg')

# %%
load_r_img = load_img('C:\\Users\\user.LAPTOP\\Desktop\\Deep Learning Projects\\Elephant_resize_img.jpg')

# %%
load_r_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200>

# %% [markdown]
# # Convert RGB images into Grayscale

# %%
import cv2

# %%
c_img = cv2.imread('C:\\Users\\user.LAPTOP\\Desktop\\Deep Learning Projects\\elephant.jfif')

# %%
type(c_img)
# Out:
# numpy.ndarray

# %%
c_img.shape
# Out:
# (563, 1000, 3)

# %%
grayscale_img = cv2.cvtColor(c_img,cv2.COLOR_RGB2GRAY)

# %%
cv2.imwrite('elephant_grayscale.jpg',grayscale_img) #Save img
# Out:
# True

# %%
gray_img = load_img(r'C:\\Users\\user.LAPTOP\\Desktop\\Deep Learning Projects\\elephant_grayscale.jpg')

# %%
gray_img
# Out:
# <PIL.Image.Image image mode=RGB size=1000x563>
